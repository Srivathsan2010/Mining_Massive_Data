# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
df1=pd.read_csv('Clean Data/24/2400.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df2=pd.read_csv('Clean Data/24/2401.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df3=pd.read_csv('Clean Data/24/2402.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df4=pd.read_csv('Clean Data/24/2403.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df5=pd.read_csv('Clean Data/24/2404.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df6=pd.read_csv('Clean Data/24/2405.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df7=pd.read_csv('Clean Data/24/2406.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df8=pd.read_csv('Clean Data/24/2407.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df9=pd.read_csv('Clean Data/24/2408.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df10=pd.read_csv('Clean Data/24/2409.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df11=pd.read_csv('Clean Data/24/2410.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df12=pd.read_csv('Clean Data/24/2411.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df13=pd.read_csv('Clean Data/24/2412.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df14=pd.read_csv('Clean Data/24/2413.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df15=pd.read_csv('Clean Data/24/2414.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df16=pd.read_csv('Clean Data/24/2415.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df17=pd.read_csv('Clean Data/24/2416.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df18=pd.read_csv('Clean Data/24/2417.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df19=pd.read_csv('Clean Data/24/2418.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df20=pd.read_csv('Clean Data/24/2419.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df21=pd.read_csv('Clean Data/24/2421.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df22=pd.read_csv('Clean Data/24/2422.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df23=pd.read_csv('Clean Data/24/2423.txt',delimiter="\t",error_bad_lines=False,low_memory=False)
df24=pd.read_csv('Clean Data/24/2424.txt',delimiter="\t",error_bad_lines=False,low_memory=False)

# %%
df1 = df1.iloc[1:]
df2 = df2.iloc[1:]
df3 = df3.iloc[1:]
df4 = df4.iloc[1:]
df5 = df5.iloc[1:]
df6 = df6.iloc[1:]
df7 = df7.iloc[1:]
df8 = df8.iloc[1:]
df9 = df9.iloc[1:]
df10 = df10.iloc[1:]
df11 = df11.iloc[1:]
df12 = df12.iloc[1:]
df13 = df13.iloc[1:]
df14 = df14.iloc[1:]
df15 = df15.iloc[1:]
df16 = df16.iloc[1:]
df17 = df17.iloc[1:]
df18 = df18.iloc[1:]
df19 = df19.iloc[1:]
df20 = df20.iloc[1:]
df21 = df21.iloc[1:]
df22 = df22.iloc[1:]
df23 = df23.iloc[1:]
df24 = df24.iloc[1:]

# %%
df1.apply(pd.to_numeric, errors='ignore')
df2.apply(pd.to_numeric, errors='ignore')
df3.apply(pd.to_numeric, errors='ignore')
df4.apply(pd.to_numeric, errors='ignore')
df5.apply(pd.to_numeric, errors='ignore')
df6.apply(pd.to_numeric, errors='ignore')
df7.apply(pd.to_numeric, errors='ignore')
df8.apply(pd.to_numeric, errors='ignore')
df9.apply(pd.to_numeric, errors='ignore')
df10.apply(pd.to_numeric, errors='ignore')
df11.apply(pd.to_numeric, errors='ignore')
df12.apply(pd.to_numeric, errors='ignore')
df13.apply(pd.to_numeric, errors='ignore')
df14.apply(pd.to_numeric, errors='ignore')
df15.apply(pd.to_numeric, errors='ignore')
df16.apply(pd.to_numeric, errors='ignore')
df17.apply(pd.to_numeric, errors='ignore')
df18.apply(pd.to_numeric, errors='ignore')
df19.apply(pd.to_numeric, errors='ignore')
df20.apply(pd.to_numeric, errors='ignore')
df21.apply(pd.to_numeric, errors='ignore')
df22.apply(pd.to_numeric, errors='ignore')
df23.apply(pd.to_numeric, errors='ignore')
df24.apply(pd.to_numeric, errors='ignore')
# Out:
#        agency_cd       site_no          datetime tz_cd  177643_72019  \
# 1           USGS  3.450511e+14  2007-10-01 01:00   EDT         30.44
# 2           USGS  3.450511e+14  2007-10-01 02:00   EDT         30.44
# 3           USGS  3.450511e+14  2007-10-01 03:00   EDT         30.44
# 4           USGS  3.450511e+14  2007-10-01 04:00   EDT         30.44
# 5           USGS  3.450511e+14  2007-10-01 05:00   EDT         30.44
# ...          ...           ...               ...   ...           ...
# 156760      USGS  3.450511e+14  2020-09-18 15:30   EDT         27.86
# 156761      USGS  3.450511e+14  2020-09-18 15:45   EDT         27.86
# 156762      USGS  3.450511e+14  2020-09-18 16:00   EDT         27.86
# 156763      USGS  3.450511e+14  2020-09-18 16:15   EDT         27.87
# 156764         #           NaN               NaN   NaN           NaN
#
#        177643_72019_cd
# 1                    A
# 2                    A
# 3                    A
# 4                    A
# ...

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24]
df = pd.concat(frames,ignore_index=True)
# Out:
# C:\Users\sriva\Miniconda3\envs\cpsc6820\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df
# Out:
#         176731_00010 176731_00010_cd 176732_00095 176732_00095_cd  \
# 0               0.00               A          NaN             NaN
# 1               0.00               A          NaN             NaN
# 2               0.00               A          NaN             NaN
# 3               0.00               A          NaN             NaN
# 4               0.00               A          NaN             NaN
# ...              ...             ...          ...             ...
# 4985288          NaN             NaN          NaN             NaN
# 4985289          NaN             NaN          NaN             NaN
# 4985290          NaN             NaN          NaN             NaN
# 4985291          NaN             NaN          NaN             NaN
# 4985292          NaN             NaN          NaN             NaN
#
#         176733_00300 176733_00300_cd 176734_00400 176734_00400_cd  \
# 0                NaN             NaN          NaN             NaN
# ...

# %%
df.dtypes
# Out:
# 176731_00010       object
# 176731_00010_cd    object
# 176732_00095       object
# 176732_00095_cd    object
# 176733_00300       object
#                     ...
# 259913_00065_cd    object
# agency_cd          object
# datetime           object
# site_no            object
# tz_cd              object
# Length: 74, dtype: object

# %%
df['176731_00010']=df['176731_00010'].astype(str).astype(float)
df['176732_00095']=df['176732_00095'].astype(str).astype(float)
df['176733_00300']=df['176733_00300'].astype(str).astype(float)
df['176734_00400']=df['176734_00400'].astype(str).astype(float)
df['176738_00045']=df['176738_00045'].astype(str).astype(float)
df['176741_00065']=df['176741_00065'].astype(str).astype(float)

# %%
df.dtypes
# Out:
# 176731_00010       float64
# 176731_00010_cd     object
# 176732_00095       float64
# 176732_00095_cd     object
# 176733_00300       float64
#                     ...
# 259913_00065_cd     object
# agency_cd           object
# datetime            object
# site_no             object
# tz_cd               object
# Length: 74, dtype: object

# %%
df['date'] = pd.to_datetime(df['datetime'], errors='coerce', format='%Y-%m-%d %H:%M:%S')
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month

# %%
df.plot(x='date', y='Temperature',kind='scatter')

# %%
#        176731       00010     Temperature, water, degrees Celsius
#        176732       00095     Specific conductance, water, unfiltered, microsiemens per centimeter at 25 degrees Celsius
#        176733       00300     Dissolved oxygen, water, unfiltered, milligrams per liter
#        176734       00400     pH, water, unfiltered, field, standard units
#        176738       00045     Precipitation, total, inches
#        176741       00065     Gage height, feet
#        259913       00065     Gage height, feet, [NAVD 88]

# %%
df.rename(columns={"176731_00010": "Temperature", "176732_00095": "Specific conductance","176733_00300": "Dissolved Oxygen","176734_00400": "pH","176738_00045": "Precipitation","176741_00065": "Gage height, feet","259913_00065": "Gage height, feet-NAVD 88" })

# %%
df_temp=df[df['176731_00010'].notnull()]
df_Specific_conductance=df[df['176732_00095'].notnull()]
df_Dissolved_oxygen=df[df['176733_00300'].notnull()]
df_pH=df[df['176734_00400'].notnull()]
df_Precipitation=df[df['176738_00045'].notnull()]
df_Gage_height=df[df['176741_00065'].notnull()]
df_Gage_height1=df[df['259913_00065'].notnull()]

# %%
df

# %%
df = df.iloc[1:]

# %%
#Time series plot

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1992-09-29', periods=1000))

ts = ts.cumsum() 

ts.plot()

# %%
#Code Comparison plot

color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange',
          'medians': 'DarkBlue', 'caps': 'Gray'}

df = pd.DataFrame(np.random.rand(10, 3), columns=['Temperature','Specific conductance','Dissolved Oxygen'])

df.plot.box(color=color)

# %%
#Datetime vs the code plot (optional)


df = pd.DataFrame(np.random.randn(1000, 2), columns=['datetime', 'Temperature'])

df['Temperature'] = df['Temperature'] + np.arange(1000)

df.plot.hexbin(x='datetime', y='Temperature', gridsize=15)

# %%
df = pd.DataFrame(np.random.randn(1000, 3), index=pd.date_range('2012', periods=1000), columns=['Temperature','Specific conductance','Dissolved Oxygen']) 

df = df.cumsum()

df.rolling(window=100).sum().plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002479597BF60>,
# ...
#       dtype=object)
